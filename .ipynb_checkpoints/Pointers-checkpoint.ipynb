# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
1+1
# Out:
# 2

# %%
print("Hello. world!")
# Out:
# Hello. world!

# %%
print("I said \"Hello, world!\"")
# Out:
# I said "Hello, world!"

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
print("There are", a, "continents on Earth")
# Out:
# There are 10 continents on Earth

# %%
b = np.array([6,3,7,4,1,5,6,9,3,6])

# %%
print(b)
# Out:
# [6 3 7 4 1 5 6 9 3 6]

# %%
len(b)
# Out:
# 10

# %%
def altitude(height, time):
    result = print(height - (9.8/2)*time**2,"metres")
# Height in metres
# Time in seconds
# The result is in metres
    return result

# %%
altitude(1000, 5)
# Out:
# 877.5 metres

# %%
3+2j
# Note that Python uses j instead of i to denote complex numbers
# Out:
# (3+2j)

# %%
print("The square root of 5 is", np.sqrt(5))
print("The square root of 5 is %.3f" % np.sqrt(5))
print("The square root of 5 is %.4f" % np.sqrt(5))
# Out:
# The square root of 5 is 2.23606797749979
# The square root of 5 is 2.236
# The square root of 5 is 2.2361

# %%
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %%
def f(x):
    return np.sin(x)

# %%
x = np.arange(-2,8,0.1)
vf = np.vectorise(f)
y = vf(x)

plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-0d7ba673d0cc> in <module>
#       1 x = np.arange(-2,8,0.1)
# ----> 2 vf = np.vectorise(f)
#       3 y = vf(x)
#       4
#       5 plt.plot(x,y)
#
# AttributeError: module 'numpy' has no attribute 'vectorise'

# %%
def FindRoot(f,a,b,tol):
    left = a
    right = b
    while right - left > tol:
